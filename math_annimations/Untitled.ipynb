# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-np.pi, np.pi, 300)
C, S = np.cos(X), np.sin(X)

# %%
ax = plt.plot(C)

# %%
t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# Out:
# Text(10, 30, '$sin(\\frac{2\\pi}{3})=\\frac{\\sqrt{3}}{2}$')

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap='jet')
C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)
# Out:
# <ipython-input-29-7e33984f27c6>:10: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
a,b = 1,1
Z = (- X**2/a**2 - Y**2/b**2)
Z_prime = -(- X**2/a**2 - Y**2/b**2)
ax.plot_surface(X, Y, Z_prime, rstride=1, cstride=1, cmap='coolwarm')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
from matplotlib.colors import Normalize
import matplotlib.cm as cm

h, w = 60,30
znew = np.random.randint(low=90, high=110, size=(60,30))
theta = np.linspace(0,2*np.pi, h)
Z = np.linspace(0,1,w)

Z,theta = np.meshgrid(Z, theta)
znew = 100 + 10*np.cos(theta/2)*np.cos(2*Z*np.pi)

R = 1
X = (R*np.cos(theta))*znew
Y = (R*np.sin(theta))*znew
true_radius = np.sqrt(X**2 + Y**2)

norm = Normalize()
colors = norm(true_radius) # auto-adjust true radius into [0,1] for color mapping

cmap = cm.get_cmap("coolwarm")
ax.plot_surface(X, Y, Z, linewidth=0, facecolors=cmap(colors), shade=True, alpha=0.75)
